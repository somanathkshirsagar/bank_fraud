# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"F:\ELLICIUM\credit_card_clients.csv")
df.head()
# Out:
#         ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0  5008804           M            Y               Y             0
# 1  5008805           M            Y               Y             0
# 2  5008806           M            Y               Y             0
# 3  5008808           F            N               Y             0
# 4  5008809           F            N               Y             0
#
#    AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 0          427500.0               Working               Higher education
# 1          427500.0               Working               Higher education
# 2          112500.0               Working  Secondary / secondary special
# 3          270000.0  Commercial associate  Secondary / secondary special
# 4          270000.0  Commercial associate  Secondary / secondary special
#
#      NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  \
# ...

# %%
shape = df.shape
print(f"There are \033[1m {shape[0]} rows\patterns \033[0m and \033[1m{shape[1]} features\033[0m.")
# Out:
# There are  36457 rows\patterns  and 20 features.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36457 entries, 0 to 36456
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   36457 non-null  int64
#  1   CODE_GENDER          36457 non-null  object
#  2   FLAG_OWN_CAR         36457 non-null  object
#  3   FLAG_OWN_REALTY      36457 non-null  object
#  4   CNT_CHILDREN         36457 non-null  int64
#  5   AMT_INCOME_TOTAL     36457 non-null  float64
#  6   NAME_INCOME_TYPE     36457 non-null  object
#  7   NAME_EDUCATION_TYPE  36457 non-null  object
#  8   NAME_FAMILY_STATUS   36457 non-null  object
#  9   NAME_HOUSING_TYPE    36457 non-null  object
#  10  DAYS_BIRTH           36457 non-null  int64
#  11  DAYS_EMPLOYED        36457 non-null  int64
#  12  FLAG_MOBIL           36457 non-null  int64
#  13  FLAG_WORK_PHONE      36457 non-null  int64
#  14  FLAG_PHONE           36457 non-null  int64
# ...

# %%
[[features,df[features].isnull().sum()] for features in df.columns if df[features].isnull().sum()>0]
# Out:
# [['OCCUPATION_TYPE', 11323]]

# %%
fig = sns.set(rc={'figure.figsize': (14, 8)})
plt.title("Heat Map for Correlation")
sns.heatmap(df.corr(), annot=True, fmt=".2f")
plt.show()

# %%
g = sns.countplot(df['target'])
g.set_xticklabels(['Bad client', ' Good client'])
plt.show()
# Out:
# c:\Users\laxman sarwade\miniconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
from sklearn.utils import resample
#create two different dataframe of majority and minority class 
df_majority = df[(df['target']==0)] 
df_minority = df[(df['target']==1)] 
# upsample minority class
df_minority_upsampled = resample(df_minority, 
replace=True,    # sample with replacement
n_samples= 35841, # to match majority class
random_state=42)  # reproducible results
# Combine majority class with upsampled minority class
df_upsampled = pd.concat([df_minority_upsampled, df_majority])

# %%
df_upsampled['target'].value_counts()
# Out:
# 1    35841
# 0    35841
# Name: target, dtype: int64

# %%
sns.countplot(df_upsampled['target'])
g = sns.countplot(df['target'])
g.set_xticklabels(['Bad client', ' Good client'])
plt.show()
# Out:
# c:\Users\laxman sarwade\miniconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# c:\Users\laxman sarwade\miniconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(20,6))
sns.countplot(x='NAME_INCOME_TYPE', data=df)
plt.show()

# %%
plt.figure(figsize=(20,6))
sns.countplot(x='NAME_EDUCATION_TYPE', data=df)
plt.show()

# %%
plt.figure(figsize=(20,6))
sns.countplot(x='NAME_HOUSING_TYPE', data=df)
plt.show()

# %%
# Item_Fat_Content column
plt.figure(figsize=(6,6))
sns.countplot(x='Item_Fat_Content', data=big_mart_data)
plt.show()

# %%
plt.figure(figsize=(6,6))
sns.countplot(df['CODE_GENDER'])
plt.show()
# Out:
# c:\Users\laxman sarwade\miniconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(6,6))
sns.countplot(df['FLAG_OWN_CAR'])
plt.show()
# Out:
# c:\Users\laxman sarwade\miniconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(6,6))
sns.histplot(df['FLAG_OWN_REALTY'])
plt.show()

# %%
plt.figure(figsize=(6,6))
sns.countplot(df['CNT_CHILDREN'])
plt.show()
# Out:
# c:\Users\laxman sarwade\miniconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(6,6))
sns.distplot(df['AMT_INCOME_TOTAL'])
plt.show()
# Out:
# c:\Users\laxman sarwade\miniconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# applying groupby() function to
# group the data on team value.
gk = df.groupby('target')

# Let's print the first entries
# in all the groups formed.
gk.first()
# Out:
#              ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# target
# 0       5008804           M            Y               Y             0
# 1       5009628           F            N               N             0
#
#         AMT_INCOME_TOTAL NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# target
# 0               427500.0          Working               Higher education
# 1               238500.0          Working  Secondary / secondary special
#
#        NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  \
# target
# 0          Civil marriage   Rented apartment      -12005          -4542
# 1                 Married  House / apartment      -19305          -3296
#
#         FLAG_MOBIL  FLAG_WORK_PHONE  FLAG_PHONE  FLAG_EMAIL OCCUPATION_TYPE  \
# target
# 0                1                1           0           0  Security staff
# 1                1                1           0           0        Laborers
#
#         CNT_FAM_MEMBERS  begin_month
# ...

# %%
gkk = df.groupby(['CODE_GENDER', 'NAME_INCOME_TYPE'])
gkk.first()
# Out:
#                                        ID FLAG_OWN_CAR FLAG_OWN_REALTY  \
# CODE_GENDER NAME_INCOME_TYPE
# F           Commercial associate  5008808            N               Y
#             Pensioner             5008812            N               Y
#             State servant         5008868            N               Y
#             Student               5010456            N               Y
#             Working               5008825            Y               N
# M           Commercial associate  5008819            Y               Y
#             Pensioner             5009133            N               Y
#             State servant         5008981            Y               Y
#             Student               5025088            N               N
#             Working               5008804            Y               Y
#
#                                   CNT_CHILDREN  AMT_INCOME_TOTAL  \
# CODE_GENDER NAME_INCOME_TYPE
# ...

# %%
df.head()
# Out:
#         ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0  5008804           M            Y               Y             0
# 1  5008805           M            Y               Y             0
# 2  5008806           M            Y               Y             0
# 3  5008808           F            N               Y             0
# 4  5008809           F            N               Y             0
#
#    AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 0          427500.0               Working               Higher education
# 1          427500.0               Working               Higher education
# 2          112500.0               Working  Secondary / secondary special
# 3          270000.0  Commercial associate  Secondary / secondary special
# 4          270000.0  Commercial associate  Secondary / secondary special
#
#      NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  \
# ...

# %%
gkk = df.groupby(['CODE_GENDER', 'NAME_FAMILY_STATUS'])
gkk.first()
# Out:
#                                        ID FLAG_OWN_CAR FLAG_OWN_REALTY  \
# CODE_GENDER NAME_FAMILY_STATUS
# F           Civil marriage        5008868            N               Y
#             Married               5008825            Y               N
#             Separated             5008812            N               Y
#             Single / not married  5008808            N               Y
#             Widow                 5008884            N               Y
# M           Civil marriage        5008804            Y               Y
#             Married               5008806            Y               Y
#             Separated             5009523            Y               N
#             Single / not married  5009056            N               Y
#             Widow                 5009133            N               Y
#
#                                   CNT_CHILDREN  AMT_INCOME_TOTAL  \
# CODE_GENDER NAME_FAMILY_STATUS
# ...
